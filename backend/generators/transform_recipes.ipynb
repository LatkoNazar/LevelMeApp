# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)

# Виводити всі стовпці без обмежень
pd.set_option('display.max_columns', None)

# Не обрізати текст у клітинках
pd.set_option('display.max_colwidth', None)

# %%
dataset = pd.read_csv("../../all_recipes.csv")

# %%
print(dataset.iloc[0,0])
# Out:
# No-Bake Nut Cookies
#
# Ingredients:
# - 1 c. firmly packed brown sugar
# - 1/2 c. evaporated milk
# - 1/2 tsp. vanilla
# - 1/2 c. broken nuts (pecans)
# - 2 Tbsp. butter or margarine
# - 3 1/2 c. bite size shredded rice biscuits
#
# Directions:
# - In a heavy 2-quart saucepan, mix brown sugar, nuts, evaporated milk and butter or margarine.
# - Stir over medium heat until mixture bubbles all over top.
# - Boil and stir 5 minutes more. Take off heat.
# - Stir in vanilla and cereal; mix well.
# - Using 2 teaspoons, drop and shape into 30 clusters on wax paper.
# - Let stand until firm, about 30 minutes.

# %%
def split_func(text):
    new_data = text.split("\n\n")
    title = new_data[0]
    ingredients = new_data[1].replace("Ingredients:\n", "").replace("- ", "").strip().split("\n")
    directions = new_data[2].replace("Directions:\n", "").replace("- ", "").strip().split("\n")
    return pd.Series([title, ingredients, directions])

# %%
df = pd.DataFrame()
df[["title", "ingredients", "directions"]] = dataset["input"].head(10).apply(lambda text: split_func(text))

# %%
df.head(2)
# Out:
#                    title  \
# 0    No-Bake Nut Cookies
# 1  Jewell Ball'S Chicken
#
#                                                                                                                                                                        ingredients  \
# 0  [1 c. firmly packed brown sugar, 1/2 c. evaporated milk, 1/2 tsp. vanilla, 1/2 c. broken nuts (pecans), 2 Tbsp. butter or margarine, 3 1/2 c. bite size shredded rice biscuits]
# 1                                                                   [1 small jar chipped beef, cut up, 4 boned chicken breasts, 1 can cream of mushroom soup, 1 carton sour cream]
#
#                                                                                                                                                                                                                                                                                                                                                   directions
# 0  [In a heavy 2-quart saucepan, mix brown sugar, nuts, evaporated milk and butter or margarine., Stir over medium heat until mixture bubbles all over top., Boil and stir 5 minutes more. Take off heat., Stir in vanilla and cereal; mix well., Using 2 teaspoons, drop and shape into 30 clusters on wax paper., Let stand until firm, about 30 minutes.]
# 1                                                                                                                                                                                       [Place chipped beef on bottom of baking dish., Place chicken on top of beef., Mix soup and cream together; pour over chicken. Bake, uncovered, at 275° for 3 hours.]

# %%
len((dataset.drop_duplicates()))
# Out:
# 2147248

# %%
import re
from fractions import Fraction

def parse_ingredient(ingredient_line):
    match = re.match(r'^(\d+\s\d+/\d+|\d+/\d+|\d+)(\s)?([a-zA-Z\.]+)?\s*(.*)', ingredient_line)
    if not match:
        return None, None, ingredient_line

    raw_amount = match.group(1)
    unit = match.group(3)
    ingredient = match.group(4)

    if ' ' in raw_amount:
        whole, frac = raw_amount.split()
        amount = float(whole) + float(Fraction(frac))
    else:
        amount = float(Fraction(raw_amount))

    unit = unit.replace('.', '').lower() if unit else None
    return amount, unit, ingredient.strip()

# %%
df["parsed_ingredients"] = df["ingredients"].apply(
    lambda lst: [parse_ingredient(ing) for ing in lst]
)

from decimal import Decimal

def clean_tuple(tup):
    return tuple(
        float(val) if isinstance(val, Decimal)
        else val.replace('c', 'cup') if isinstance(val, str) and val == 'c'
        else val
        for val in tup
    )

df["parsed_ingredients"] = df["parsed_ingredients"].apply(
    lambda lst: [clean_tuple(tup) for tup in lst]
)

df["parsed_ingredients"]
# Out:
# 0                                                                                                                                                                         [(1.0, cup, firmly packed brown sugar), (0.5, cup, evaporated milk), (0.5, tsp, vanilla), (0.5, cup, broken nuts (pecans)), (2.0, tbsp, butter or margarine), (3.5, cup, bite size shredded rice biscuits)]
# 1                                                                                                                                                                                                                                              [(1.0, small, jar chipped beef, cut up), (4.0, boned, chicken breasts), (1.0, can, cream of mushroom soup), (1.0, carton, sour cream)]
# 2                                                                                                                                                                                 [(2.0, None, (16 oz.) pkg. frozen corn), (1.0, None, (8 oz.) pkg. cream cheese, cubed), (0.3333333333333333, cup, butter, cubed), (0.5, tsp, garlic powder), (0.5, tsp, salt), (0.25, tsp, pepper)]
# 3                                                                                                                                                                          [(1.0, large, whole chicken), (2.0, None, (10 1/2 oz.) cans chicken gravy), (1.0, None, (10 1/2 oz.) can cream of mushroom soup), (1.0, None, (6 oz.) box Stove Top stuffing), (4.0, oz, shredded cheese)]
# 4                                                                                                                                                                                                                [(1.0, cup, peanut butter), (0.75, cup, graham cracker crumbs), (1.0, cup, melted butter), (1.0, lb, (3 1/2 c.) powdered sugar), (1.0, large, pkg. chocolate chips)]
# 5    [(6.0, baking, potatoes), (1.0, lb, of extra lean ground beef), (0.6666666666666666, cup, butter or margarine), (6.0, cup, milk), (0.75, tsp, salt), (0.5, tsp, pepper), (1.5, cup, (6 oz.) shredded Cheddar cheese, divided), (12.0, sliced, bacon, cooked, crumbled and divided), (4.0, green, onion, chopped and divided), (1.0, None, (8 oz.) carton sour cream (optional))]
# 6                                                                                                                                                                  [(1.5, cup, sugar), (0.5, cup, butter), (1.0, egg, ), (1.0, cup, buttermilk), (2.0, cup, flour), (0.5, tsp, salt), (1.0, tsp, soda), (1.0, cup, buttermilk), (2.0, cup, rhubarb, finely cut), (1.0, tsp, vanilla)]
# 7                                                                                                                                                                           [(1.0, can, cream-style corn), (1.0, can, whole kernel corn), (0.5, pkg, (approximately 20) saltine crackers, crushed), (1.0, egg, , beaten), (6.0, tsp, butter, divided), (None, None, pepper to taste)]
# 8                                                                                                                                             [(1.5, lb, round steak (1-inch thick), cut into strips), (1.0, can, drained tomatoes, cut up (save liquid)), (1.75, cup, water), (0.5, cup, onions), (1.5, tbsp, Worcestershire sauce), (2.0, green, peppers, diced), (0.25, cup, oil)]
# 9                                                                                                                                                                                                            [(1.0, large, container Cool Whip), (1.0, large, can crushed pineapple), (1.0, can, condensed milk), (3.0, lemons, ), (1.0, cup, pecans), (2.0, graham, cracker crusts)]
# Name: parsed_ingredients, dtype: object

# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from backend.api.app import create_app, db

app = create_app()

with app.app_context():
    nutrient_df = pd.read_sql("SELECT * FROM nutrient_info", db.engine)

# %%
import pandas as pd
import re
import spacy
from tqdm import tqdm

nlp = spacy.load("en_core_web_md")
tqdm.pandas()

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    return text.strip()

def lemmatize_text(text):
    doc = nlp(text)
    return " ".join([token.lemma_ for token in doc if not token.is_stop and not token.is_punct])

def get_vector(text):
    return nlp(text).vector

def preprocess_dataframe(df, text_col):
    df["cleaned"] = df[text_col].apply(clean_text)
    df["lemmatized"] = df["cleaned"].progress_apply(lemmatize_text)
    df["vector"] = df["lemmatized"].progress_apply(get_vector)
    df["category"] = df["description"].apply(lambda x: x.split(",")[0].strip())
    df["category"] = df["category"].apply(lemmatize_text)
    return df

nutrient_df = preprocess_dataframe(nutrient_df, "description")
# Out:
# 100%|██████████| 85149/85149 [06:46<00:00, 209.70it/s]
# 100%|██████████| 85149/85149 [07:25<00:00, 191.08it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def find_most_similar(text, df, top_k=1):
    cleaned = clean_text(text)
    lemmatized = lemmatize_text(cleaned)
    vec = get_vector(lemmatized).reshape(1, -1)

    # Порівняння з векторами в таблиці
    vectors = np.vstack(df["vector"].values)
    similarities = cosine_similarity(vec, vectors)[0]

    # Вибір топ-K найближчих
    top_k_indices = similarities.argsort()[::-1][:top_k]
    results = df.iloc[top_k_indices].copy()
    results["similarity"] = similarities[top_k_indices]
    return results

# %%
import csv
nutrient_df.to_csv("nutrient_table_vectorized.csv", index=False, encoding="utf-8-sig", quoting=csv.QUOTE_ALL)

# %%
resultTFIDF = pd.DataFrame()
for ingredient in df["parsed_ingredients"].to_list():
    for tup in ingredient:
        ingredient_name = tup[2]
        resultTFIDF = pd.concat([resultTFIDF, find_most_similar("rice brown", nutrient_df)["description"]], axis=0)
resultTFIDF
# Out:
#              description
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown
# 69777  Rice flour, brown

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

corpus = nutrient_df["cleaned"].tolist()

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(corpus)

def filter_and_prioritize_by_category(df, query):
    query_words = set(clean_text(query).split())

    def get_overlap_score(category):
        if pd.isna(category):
            return 0, float('inf')
        cat_words = set(clean_text(category).split())
        return len(query_words & cat_words), len(cat_words)

    df = df.copy()
    df[["overlap_score", "category_length"]] = df["category"].apply(get_overlap_score).apply(pd.Series)

    df = df.sort_values(["overlap_score", "category_length"], ascending=[False, True])
    return df

def tfidf_search(query, measure, top_k=1):
    query_clean = clean_text(query)

    candidates = nutrient_df[nutrient_df["measure"] == measure].copy()

    #
    candidates_category = filter_and_prioritize_by_category(candidates, query)
    if not candidates_category.empty:
        candidates = candidates_category.copy()

    corpus = candidates["cleaned"].tolist()
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(corpus)

    query_vec = vectorizer.transform([query_clean])
    sims = cosine_similarity(query_vec, tfidf_matrix)[0]

    top_k_idx = sims.argsort()[::-1][:top_k]
    results = candidates.iloc[top_k_idx].copy()
    results["similarity"] = sims[top_k_idx]
    return results

result = pd.DataFrame()
for ingredient in df["parsed_ingredients"].to_list():
    for tup in ingredient:
        ingredient_name = tup[2]
        result = pd.concat([result, tfidf_search(ingredient_name, tup[1])], axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10172\3823915708.py in ?()
#      46 result = pd.DataFrame()
#      47 for ingredient in df["parsed_ingredients"].to_list():
#      48     for tup in ingredient:
#      49         ingredient_name = tup[2]
# ---> 50         result = pd.concat([result, tfidf_search(ingredient_name, tup[1])], axis=0)
#
# ~\AppData\Local\Temp\ipykernel_10172\3823915708.py in ?(query, measure, top_k)
#      26
#      27     candidates = nutrient_df[nutrient_df["measure"] == measure].copy()
#      28
#      29     #
# ---> 30     candidates_category = filter_and_prioritize_by_category(candidates, query)
#      31     if not candidates_category.empty:
#      32         candidates = candidates_category.copy()
#      33
#
# ~\AppData\Local\Temp\ipykernel_10172\3823915708.py in ?(df, query)
#      15         cat_words = set(clean_text(category).split())
#      16         return len(query_words & cat_words), len(cat_words)
#      17
#      18     df = df.copy()
# ---> 19     df[["overlap_score", "category_length"]] = df["category"].apply(get_overlap_score).apply(pd.Series)
#      20
#      21     df = df.sort_values(["overlap_score", "category_length"], ascending=[False, True])
#      22     return df
#
# c:\Users\Nazar Latko\.pyenv\pyenv-win\versions\3.11.5\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4295
#    4296         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
#    4301             self._set_item_frame_value(key, value)
#    4302         elif (
#
# c:\Users\Nazar Latko\.pyenv\pyenv-win\versions\3.11.5\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4354                 value = DataFrame(value).values
#    4355                 return self._setitem_array(key, value)
#    4356
#    4357             else:
# -> 4358                 self._iset_not_inplace(key, value)
#
# c:\Users\Nazar Latko\.pyenv\pyenv-win\versions\3.11.5\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4373                 return obj[i]
#    4374
#    4375         if self.columns.is_unique:
#    4376             if np.shape(value)[-1] != len(key):
# -> 4377                 raise ValueError("Columns must be same length as key")
#    4378
#    4379             for i, col in enumerate(key):
#    4380                 self[col] = igetitem(value, i)
#
# ValueError: Columns must be same length as key

# %%
result[["category", "description"]]
# Out:
#               category  \
# 78766        sweetener
# 52892             milk
# 82014  vanilla extract
# 55927              nut
# 23640           butter
# 25309            candy
# 1053             apple
#
#                                                                               description
# 78766                                     Sweeteners, sugar substitute, granulated, brown
# 52892                                      Milk, canned, evaporated, with added vitamin A
# 82014                                                                     Vanilla extract
# 55927                                          Nuts, pecans, oil roasted, with salt added
# 23640                                                                Butter, without salt
# 25309                     Candies, MARS SNACKFOOD US, SKITTLES Original Bite Size Candies
# 1053   Apples, raw, fuji, with skin (Includes foods for USDA's Food Distribution Program)

# %%
for ingredient in df["parsed_ingredients"].to_list():
    for tup in ingredient:
        print(tup[2])
# Out:
# firmly packed brown sugar
# evaporated milk
# vanilla
# broken nuts (pecans)
# butter or margarine
# bite size shredded rice biscuits

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

corpus = nutrient_df["cleaned"].tolist()

vectorizer = CountVectorizer()
count_matrix = vectorizer.fit_transform(corpus)

def countvec_search(query, measure, top_k=5):
    query_clean = clean_text(query)
    query_vec = vectorizer.transform([query_clean])
    sims = cosine_similarity(query_vec, count_matrix)[0]

    filtered_df = nutrient_df[nutrient_df["measure"] == measure]
    filtered_matrix = count_matrix[filtered_df.index]

    sims_filtered = cosine_similarity(query_vec, filtered_matrix)[0]

    top_k_idx = sims_filtered.argsort()[::-1][:top_k]
    results = filtered_df.iloc[top_k_idx].copy()
    results["similarity"] = sims_filtered[top_k_idx]
    return results

resultCount = pd.DataFrame()
for ingredient in df["parsed_ingredients"].to_list():
    for tup in ingredient:
        ingredient_name = tup[2]
        resultCount = pd.concat([resultCount, tfidf_search(ingredient_name, tup[1])], axis=0)
resultCount["description"]
# Out:
# 78766                    Sweeteners, sugar substitute, granulated, brown
# 52892                     Milk, canned, evaporated, with added vitamin A
# 82014                                                    Vanilla extract
# 55927                         Nuts, pecans, oil roasted, with salt added
# 23640                                               Butter, without salt
# 25309    Candies, MARS SNACKFOOD US, SKITTLES Original Bite Size Candies
# Name: description, dtype: object
